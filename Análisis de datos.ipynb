# %% [markdown]
# En el repositorio encontrará la información relacionada con hospedajes registrados en Airbnb en la ciudad de Berlín, Alemania. Examine, depure y si es pertinente unifique algunas de las fuentes de información contenida en dicho repositorio para darle solución a las siguientes tareas:

# %%
import numpy as np # Para operaciones matriciales
import pandas as pd # Para leer csv y procesar datos
import matplotlib.pyplot as plt # Para visualizar datos

# %%
dataset = pd.read_csv('listings.csv')
dataset.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
# ...

# %%
selected_features = ["neighbourhood","room_type", "number_of_reviews",
                     "calculated_host_listings_count",
                     "availability_365","longitude","latitude","price"]
dataset = dataset[selected_features]
dataset.head(5)
datasetnum = dataset.drop(['neighbourhood', 'room_type'], axis =1)
# Out:
#               neighbourhood        room_type  number_of_reviews  \
# 0           Brunnenstr. Süd  Entire home/apt                118
# 1  Prenzlauer Berg Nordwest     Private room                  6
# 2   Prenzlauer Berg Südwest  Entire home/apt                143
# 3           Schöneberg-Nord     Private room                 25
# 4            Helmholtzplatz     Private room                197
#
#    calculated_host_listings_count  availability_365  longitude   latitude  \
# 0                               4               141  13.402557  52.534537
# 1                               1                 0  13.404553  52.548513
# 2                               1               220  13.417579  52.534996
# 3                               1               297  13.349065  52.498855
# 4                               1                26  13.415091  52.543157
#
#    price
# 0     60
# 1     17
# 2     90
# 3     26
# 4     42

# %%
# funcion para detectar outliers
def detect_outlier(dataset):
    feature_outliers=[]
    threshold=7
    mean_1 = np.mean(dataset)
    std_1 =np.std(dataset)
    
    counter=0
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            feature_outliers.append(counter)
        counter += 1
    return feature_outliers

# %%
#split data test and train
from sklearn.model_selection import train_test_split

X = clean_data.drop(["price"],axis=1)
y = clean_data["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-490697ffcfb8> in <module>
#       1 #split data test and train
# ----> 2 from sklearn.model_selection import train_test_split
#       3
#       4 X = clean_data.drop(["price"],axis=1)
#       5 y = clean_data["price"]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Out:
#   File "<ipython-input-53-e8e4cf8cf43e>", line 2
#     dataset.columns[]
#                     ^
# SyntaxError: invalid syntax
